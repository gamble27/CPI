# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %%
from os import listdir, chdir
from os.path import isfile, join

data_loc = "/home/olga/Projects/CPI/dataset"
datasets = [f for f in listdir(data_loc) if isfile(join(data_loc, f))]

# %%
cpi_csv = list(filter(lambda dataset: True if 'cpi' in dataset else False,
                 datasets))[0]

chdir(data_loc)

df = pd.read_csv(cpi_csv)
df = df.dropna()

for f in datasets:
    if f == cpi_csv:
        continue 
    df1 = pd.read_csv(f)
    df = pd.merge(df, df1)
    
del df1

# %%
idx_start = f"{df.iloc[0,2]}-{df.iloc[0,3]}-1"
idx_end = f"{df.iloc[df.shape[0]-1,2]}-{df.iloc[df.shape[0]-1,3]}-1"
dates = pd.date_range(idx_start, idx_end, freq='M')
#df['Date'] = dates

# %%
df.columns
# Out:
# Index(['Country', 'Code', 'Year', 'Month', 'Consumer Price Index (CPI)',
#        'Inflation monthly percent change in the CPI',
#        'Inflation annual percent change in the CPI',
#        'Employment million people', 'Unemployment rate percent',
#        'Labor cost index', 'Minimum wage', 'Economic (GDP) growth percent',
#        'Industrial production annual percent change', 'Retail sales Y-on-Y',
#        'House price index', 'Building permits',
#        'Real residential property prices Y-on-Y percent change',
#        'Business confidence survey',
#        'Current account balance million currency units',
#        'Exports million currency units',
#        'Foreign exchange reserves billion currency units',
#        'Foreign direct investment million currency units',
#        'Government expenditure billion currency units',
#        'Budget balance million currency units', 'Sovereign credit ratings',
#        'Government bond 10-year yield percent', 'Government debt',
#        'Household consumption billion currency units',
#        'Consumption as percent of GDP', 'Consumption growth',
#        'Investment billion currency units', 'Investment as percent of GDP',
#        'Investment growth', 'Money supply billion currency units',
#        'Private sector credit billion currency units',
#        'Business credit billion currency units',
#        'Household credit billion currency units',
#        'Mortgage credit billion currency units',
#        'Consumer credit billion currency units',
#        'Bank deposit interest rate percent',
#        'Business credit interest rate percent',
#        'Mortgage credit interest rate percent', 'Credit gap',
#        'Debt service ratios for private non-financial sector',
#        'Exchange rate USD'],
#       dtype='object')

# %%
percent_missing = df.isna().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#                                                                                           column_name  \
# Government debt                                                                       Government debt
# Labor cost index                                                                     Labor cost index
# Debt service ratios for private non-financial s...  Debt service ratios for private non-financial ...
# Credit gap                                                                                 Credit gap
# Real residential property prices Y-on-Y percent...  Real residential property prices Y-on-Y percen...
# Government bond 10-year yield percent                           Government bond 10-year yield percent
# House price index                                                                   House price index
# Sovereign credit ratings                                                     Sovereign credit ratings
# Building permits                                                                     Building permits
# Business confidence survey                                                 Business confidence survey
# Consumer credit billion currency units                         Consumer credit billion currency units
# Foreign exchange reserves billion currency units     Foreign exchange reserves billion currency units
# Budget balance million currency units                           Budget balance million currency units
# Foreign direct investment million currency units     Foreign direct investment million currency units
# Current account balance million currency units         Current account balance million currency units
# Exports million currency units                                         Exports million currency units
# Retail sales Y-on-Y                                                               Retail sales Y-on-Y
# Mortgage credit billion currency units                         Mortgage credit billion currency units
# Household credit billion currency units                       Household credit billion currency units
# Business credit billion currency units                         Business credit billion currency units
# Bank deposit interest rate percent                                 Bank deposit interest rate percent
# Business credit interest rate percent                           Business credit interest rate percent
# Mortgage credit interest rate percent                           Mortgage credit interest rate percent
# Private sector credit billion currency units             Private sector credit billion currency units
# Exchange rate USD                                                                   Exchange rate USD
# Investment growth                                                                   Investment growth
# Consumption growth                                                                 Consumption growth
# Industrial production annual percent change               Industrial production annual percent change
# Investment billion currency units                                   Investment billion currency units
# Investment as percent of GDP                                             Investment as percent of GDP
# Government expenditure billion currency units           Government expenditure billion currency units
# Consumption as percent of GDP                                           Consumption as percent of GDP
# Household consumption billion currency units             Household consumption billion currency units
# Unemployment rate percent                                                   Unemployment rate percent
# Employment million people                                                   Employment million people
# Money supply billion currency units                               Money supply billion currency units
# Code                                                                                             Code
# Economic (GDP) growth percent                                           Economic (GDP) growth percent
# Minimum wage                                                                             Minimum wage
# Inflation annual percent change in the CPI                 Inflation annual percent change in the CPI
# Inflation monthly percent change in the CPI               Inflation monthly percent change in the CPI
# Consumer Price Index (CPI)                                                 Consumer Price Index (CPI)
# Month                                                                                           Month
# Year                                                                                             Year
# Country                                                                                       Country
#
#                                                     percent_missing
# Government debt                                          100.000000
# Labor cost index                                         100.000000
# Debt service ratios for private non-financial s...       100.000000
# Credit gap                                               100.000000
# Real residential property prices Y-on-Y percent...       100.000000
# Government bond 10-year yield percent                    100.000000
# House price index                                        100.000000
# Sovereign credit ratings                                 100.000000
# Building permits                                          95.774648
# Business confidence survey                                84.507042
# Consumer credit billion currency units                    71.830986
# Foreign exchange reserves billion currency units          59.154930
# Budget balance million currency units                     52.112676
# Foreign direct investment million currency units          45.070423
# Current account balance million currency units            39.436620
# Exports million currency units                            39.436620
# Retail sales Y-on-Y                                       28.169014
# Mortgage credit billion currency units                    22.535211
# Household credit billion currency units                   22.535211
# Business credit billion currency units                    22.535211
# Bank deposit interest rate percent                        22.535211
# Business credit interest rate percent                     22.535211
# Mortgage credit interest rate percent                     22.535211
# Private sector credit billion currency units              22.535211
# Exchange rate USD                                         14.084507
# Investment growth                                          7.042254
# Consumption growth                                         7.042254
# Industrial production annual percent change                5.633803
# Investment billion currency units                          1.408451
# Investment as percent of GDP                               1.408451
# Government expenditure billion currency units              1.408451
# Consumption as percent of GDP                              1.408451
# Household consumption billion currency units               1.408451
# Unemployment rate percent                                  1.408451
# Employment million people                                  1.408451
# Money supply billion currency units                        0.000000
# Code                                                       0.000000
# Economic (GDP) growth percent                              0.000000
# Minimum wage                                               0.000000
# Inflation annual percent change in the CPI                 0.000000
# Inflation monthly percent change in the CPI                0.000000
# Consumer Price Index (CPI)                                 0.000000
# Month                                                      0.000000
# Year                                                       0.000000
# Country                                                    0.000000

# %%
columns_to_remove = [
    row[1]['column_name'] for row in missing_value_df.iterrows()
    if row[1]['percent_missing'] >= 0.75
]
#df = df.drop(columns=columns_to_remove)
sorted(df.columns)
# Out:
# ['Bank deposit interest rate percent',
#  'Budget balance million currency units',
#  'Building permits',
#  'Business confidence survey',
#  'Business credit billion currency units',
#  'Business credit interest rate percent',
#  'Code',
#  'Consumer Price Index (CPI)',
#  'Consumer credit billion currency units',
#  'Consumption as percent of GDP',
#  'Consumption growth',
#  'Country',
#  'Credit gap',
#  'Current account balance million currency units',
#  'Debt service ratios for private non-financial sector',
#  'Economic (GDP) growth percent',
#  'Employment million people',
#  'Exchange rate USD',
#  'Exports million currency units',
#  'Foreign direct investment million currency units',
#  'Foreign exchange reserves billion currency units',
#  'Government bond 10-year yield percent',
#  'Government debt',
#  'Government expenditure billion currency units',
#  'House price index',
#  'Household consumption billion currency units',
#  'Household credit billion currency units',
#  'Industrial production annual percent change',
#  'Inflation annual percent change in the CPI',
#  'Inflation monthly percent change in the CPI',
#  'Investment as percent of GDP',
#  'Investment billion currency units',
#  'Investment growth',
#  'Labor cost index',
#  'Minimum wage',
#  'Money supply billion currency units',
#  'Month',
#  'Mortgage credit billion currency units',
#  'Mortgage credit interest rate percent',
#  'Private sector credit billion currency units',
#  'Real residential property prices Y-on-Y percent change',
#  'Retail sales Y-on-Y',
#  'Sovereign credit ratings',
#  'Unemployment rate percent',
#  'Year']

# %%
sns.pairplot(df[[
    'Consumer Price Index (CPI)',
    'Inflation annual percent change in the CPI',
    'Economic (GDP) growth percent',
    'Money supply billion currency units'
]].dropna())

# %%
corr = df.corr()
plot = sns.heatmap(corr)
chdir('/home/olga/Projects/CPI/Regression')
plot.get_figure().savefig('figure.jpg', dpi=700)
